# %% [markdown]
# <a href="https://colab.research.google.com/github/wdesich/BTE320/blob/main/BTE320Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
# Compound Interest Calculator

years = 2
rate = .03
principle = 3000

finalAmount = principle * (1 + rate) ** years

print(finalAmount)
# Out:
# 3182.7

# %%
print(1,3)
# prints 1 and 3, "1 3\n" with a sep in the middle and end at the end so next line of code prints to next line
# sep = " "

print("1\n3")
# prints 1 above 3
# end = "\n" = start of next line###
# Out:
# 1 3
# 1
# 3

# %%
print("Principle:",principle)
print("Interest Rate:",rate)
print("Number of Years:",years)
#print function automatically adds an end "\n"

print("\nPrinciple:",principle, end="---")
print("Interest Rate:",rate, end="---")
print("Number of Years:",years)
#end can be replaced so new print calls print on the same line
# Out:
# Principle: 3000
# Interest Rate: 0.03
# Number of Years: 2
#
# Principle: 3000---Interest Rate: 0.03---Number of Years: 2

# %%
print("Interest Rate:", rate, sep=">>>", end="&&&")
print("Number of Years:", years)
#Can change sep and end to anything
#End is by default \n
# Out:
# Interest Rate:>>>0.03&&&Number of Years: 2

# %%
print("Interest Rate:", rate, "; Number of Years:", years)
#Can format in print
# Out:
# Interest Rate: 0.03 ; Number of Years: 2

# %%
print("Interest Rate: {} ; Number of Years: {}".format(rate, years))
# Or can format string itself before calling print
# Out:
# Interest Rate: 0.03 ; Number of Years: 2

# %%
grade = float(input("Enter grade (0-100): "))

if grade >= 97:
  print("A+")
elif grade >= 93:
  print("A")
elif grade >= 90:
  print("A-")
# Out:
# Enter grade (0-100): 95
# A

# %%
email = "URGENT! Click on the link www.spam.org"
has_urgent = "URGENT!"
has_link = "www"

if has_urgent in email:
  if has_link in email:
    print("Phishing!")
  else:
    print("Spam")
elif has_link in email:
  print("Spam")
else:
  print("Email is safe.")

if has_link in email:
  print("Phishing!")
elif has_urgent in email:
  print("Spam")
else:
  print("Email is safe.")
# Out:
# Phishing!
# Phishing!

# %%
email = "URGENT! Click on the link www.spam.org"
has_urgent = "URGENT!"
has_link = "www"

if has_urgent in email and has_link in email:
  print("Phishing!")
elif has_urgent in email:
  print("Spam")
else:
  print("Email is safe.")

#

# %%
# While loops stuff
check = input("Print greeting (y/n): ")
while check == 'Y':
  name = input("Give me a name: ")
  print(f"Hello, {name}")
  check = input("Do you want to continue (y/n)? ")

# %%
# Goes on forever
#while True:
  #print("Bruh")
